# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
# %matplotlib inline

# %%
x=np.array([2,5,6,1,2,4,6,7,9,12,5,2,7,15,23,54,18,39],float)
y=x/np.max(x)

# %%
y
# Out:
# array([ 0.03703704,  0.09259259,  0.11111111,  0.01851852,  0.03703704,
#         0.07407407,  0.11111111,  0.12962963,  0.16666667,  0.22222222,
#         0.09259259,  0.03703704,  0.12962963,  0.27777778,  0.42592593,
#         1.        ,  0.33333333,  0.72222222])

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
a1 = np.random.randint(10,50,20)

# %%
a2 = (a1 - np.mean(a1))/np.std(a1)

# %%
a1
# Out:
# array([43, 20, 12, 22, 45, 19, 11, 30, 37, 18, 40, 11, 40, 27, 33, 41, 44,
#        24, 24, 38])

# %%
a2
# Out:
# array([ 1.24017399, -0.79000407, -1.49615296, -0.61346685,  1.41671121,
#        -0.87827268, -1.58442157,  0.09268204,  0.71056232, -0.96654129,
#         0.97536815, -1.58442157,  0.97536815, -0.17212379,  0.35748788,
#         1.06363676,  1.3284426 , -0.43692963, -0.43692963,  0.79883093])

# %%
plt.plot(a1)

# %%
plt.plot(a2)

# %%
import sklearn.preprocessing as skp

# %%
y1=skp.normalize(x[None,:])

# %%
y1.shape
# Out:
# (1, 18)

# %%
plt.plot(y1[0])

# %%
y2=skp.minmax_scale(x,(10,20))

# %%
y2
# Out:
# array([ 10.18867925,  10.75471698,  10.94339623,  10.        ,
#         10.18867925,  10.56603774,  10.94339623,  11.13207547,
#         11.50943396,  12.0754717 ,  10.75471698,  10.18867925,
#         11.13207547,  12.64150943,  14.1509434 ,  20.        ,
#         13.20754717,  17.16981132])

# %%
plt.plot(y2)
